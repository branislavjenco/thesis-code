# %%
# %matplotlib notebook
import h5py

path = '/home/branislav/Downloads/h5_files/main_split/training_objectdataset.h5'

f = h5py.File(path, 'r')
number = 500

# %%
random_pc = f['data'][number]

# %%
from pyntcloud import PyntCloud

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({"x": random_pc[:,0], "y": random_pc[:,1], "z": random_pc[:,2] })
p = PyntCloud(df)
print(f['label'][number])
p.plot()
# Out:
# 3
# <img src="data:image/png;base64,..." width="1000">

# %%
# Out:
# 3
